# %%
# !pip install ..
# Out:
# '/Users/sarahrandall/Python-outbreak-info/src/outbreak_data'

# %%
import os; os.chdir('/Users/sarahrandall/Python-outbreak-info/src/outbreak_data')
print(os.getcwd())
# Out:
# /Users/sarahrandall/Python-outbreak-info/src/outbreak_data

# %%
from outbreak_data import outbreak_data
# from outbreak_data.authenticate_user import set_authentication

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import hsv_to_rgb

# %%
import auth_token
set_authentication(auth_token.get_auth_token())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 set_authentication()
#
# TypeError: set_authentication() missing 1 required positional argument: 'token'

# %%
df = outbreak_data.all_lineage_prevalences("USA_US-HI")

#{ ‘location’: ‘USA_US-HI’ }

# %%
print(df)
# Out:
#                     total_count  lineage_count  prevalence  prevalence_rolling
# date       lineage
# 2023-08-05 HV.1              17              1    0.058824            0.054264
# 2023-08-06 HV.1               0              0    0.000000            0.026022
# 2023-08-07 HV.1               0              0    0.000000            0.015317
# 2023-08-08 HV.1              18              1    0.055556            0.023569
# 2023-08-09 HV.1               0              0    0.000000            0.020619
# ...                         ...            ...         ...                 ...
# 2024-04-23 OTHER              9              6    0.666667            0.750000
# 2024-04-24 OTHER              5              3    0.600000            0.703704
# 2024-04-25 OTHER              0              0    0.000000            0.714286
# 2024-04-26 OTHER              0              0    0.000000            0.684211
# 2024-04-27 OTHER              1              1    1.000000            0.722222
#
# [2359 rows x 4 columns]

# %%
df = outbreak_data.cases_by_location("USA_US-CO", 2)
print(df)
# Out:
#                               confirmed_numIncrease  confirmed_rolling
# location          date
# USA_Colorado_None 2020-02-12                      0           0.000000
#                   2020-02-13                      0           0.000000
#                   2020-02-14                      0           0.000000
#                   2020-02-15                      0           0.000000
#                   2020-02-16                      0           0.000000
# ...                                             ...                ...
#                   2023-03-04                      0         436.000000
#                   2023-03-05                      0         436.000000
#                   2023-03-06                    553         440.428558
#                   2023-03-07                      0         440.428558
#                   2023-03-08                    827         438.428558
#
# [1121 rows x 2 columns]

# %%
t2 = outbreak_data.mutation_details('s:a262a')
t2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 t2 = outbreak_data.mutation_details('s:a262a')
#       2 t2
#
# File ~/opt/anaconda3/envs/spyder-env/lib/python3.9/site-packages/outbreak_data/outbreak_data.py:85, in mutation_details(mutations, **req_args)
#      77 """Get details of one or more mutations from clinical data.
#      78
#      79  :param mutations: Mutation or list of mutations of interest.
#    (...)
#      82
#      83  :Parameter example: {'mutations':'s:e484*'} """
#      84 mutations = ','.join(_list_if_str(mutations))
# ---> 85 data = _get_outbreak_data('genomics/mutation-details', f'mutations={mutations}', collect_all=False, **req_args)
#      86 return pd.DataFrame(data['results']).set_index('mutation')
#
# File ~/opt/anaconda3/envs/spyder-env/lib/python3.9/site-packages/outbreak_data/outbreak_data.py:62, in _get_outbreak_data(endpoint, argstring, server, auth, collect_all, curr_page)
#      60     raise ValueError('Warning!: Potentially missing endpoint. Data not being returned by server.')
#      61 if 400 <= in_req.status_code <= 499:
# ---> 62     raise NameError(f'Request error (client-side/Error might be endpoint): {in_req.status_code}')
#      63 elif 500 <= in_req.status_code <= 599:
#      64     raise NameError(f'Request error (server-side): {in_req.status_code}')
#
# NameError: Request error (client-side/Error might be endpoint): 403

# %%
df = outbreak_data.daily_lag('USA_US-HI')
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df = outbreak_data.daily_lag('USA_US-HI')
#       2 print(df)
#
# File ~/opt/anaconda3/envs/spyder-env/lib/python3.9/site-packages/outbreak_data/outbreak_data.py:171, in daily_lag(location, **req_args)
#     163 """Get the daily lag between collection and submission dates of clinical sequences in a location.
#     164
#     165  :param location: A string containing a location ID. If not specified, return lag globally.
#    (...)
#     168
#     169  :Parameter example: { 'location': 'USA_US-HI' } """
#     170 query = f'location_id={location}' if location is not None else ''
# --> 171 data = _get_outbreak_data('genomics/collection-submission', query, collect_all=False, **req_args)
#     172 return pd.DataFrame(data['results']).set_index(['date_collected', 'date_submitted'])
#
# File ~/opt/anaconda3/envs/spyder-env/lib/python3.9/site-packages/outbreak_data/outbreak_data.py:62, in _get_outbreak_data(endpoint, argstring, server, auth, collect_all, curr_page)
#      60     raise ValueError('Warning!: Potentially missing endpoint. Data not being returned by server.')
#      61 if 400 <= in_req.status_code <= 499:
# ---> 62     raise NameError(f'Request error (client-side/Error might be endpoint): {in_req.status_code}')
#      63 elif 500 <= in_req.status_code <= 599:
#      64     raise NameError(f'Request error (server-side): {in_req.status_code}')
#
# NameError: Request error (client-side/Error might be endpoint): 403

# %%
df = outbreak_data.growth_rates('BA.2.86', 'USA')  #BA.2 works too
#Get growth rate data for BA.2.86 on 2024-02-02
df.loc['USA','BA.2.86','2024-02-02']
# Out:
#                                   G_7  G_7_linear  N_7  N_prev_7  \
# location lineage date
# USA      BA.2.86 2024-01-30  0.034127    3.471641  0.0       2.0
#                  2024-01-31  0.034722    3.533181  0.0       2.0
#                  2024-02-01  0.028671    2.908555  0.0       1.0
#                  2024-02-02  0.030113    3.057071  0.0       1.0
#                  2024-02-03  0.031394    3.189245  0.0       1.0
#
#                              Prevalence_7  Prevalence_7_percentage  \
# location lineage date
# USA      BA.2.86 2024-01-30      0.002220                 0.222041
#                  2024-01-31      0.002261                 0.226051
#                  2024-02-01      0.002256                 0.225575
#                  2024-02-02      0.002365                 0.236476
#                  2024-02-03      0.002483                 0.248282
#
#                              confidenceInterval20  confidenceInterval35  \
# location lineage date
# USA      BA.2.86 2024-01-30              1.010083              1.818149
#                  2024-01-31              1.025535              1.845963
#                  2024-02-01              1.038099              1.868578
#                  2024-02-02              1.044012              1.879221
#                  2024-02-03              1.050281              1.890505
#
#                              confidenceInterval5  confidenceInterval50  ...  \
# location lineage date                                                   ...
# USA      BA.2.86 2024-01-30             0.242420              2.707022  ...
#                  2024-01-31             0.246128              2.748434  ...
#                  2024-02-01             0.249144              2.782106  ...
#                  2024-02-02             0.250563              2.797951  ...
#                  2024-02-03             0.252067              2.814752  ...
#
#                              confidenceInterval80  confidenceInterval95  \
# location lineage date
# USA      BA.2.86 2024-01-30              5.171625              7.919050
#                  2024-01-31              5.250739              8.040194
#                  2024-02-01              5.315067              8.138697
#                  2024-02-02              5.345340              8.185052
#                  2024-02-03              5.377437              8.234200
#
#                              deltaG_7  deltaG_7_linear  deltaN_7  \
# location lineage date
# USA      BA.2.86 2024-01-30  0.039048         4.040332    3108.0
#                  2024-01-31  0.039621         4.102140    3108.0
#                  2024-02-01  0.040350         4.152396    3108.0
#                  2024-02-02  0.040522         4.176047    3108.0
#                  2024-02-03  0.040713         4.201122    3108.0
#
#                              deltaN_prev_7  deltaPrevalence_7  \
# location lineage date
# USA      BA.2.86 2024-01-30       1.579737           0.646176
#                  2024-01-31       1.579737           0.663847
#                  2024-02-01       1.630381           0.698774
#                  2024-02-02       1.582951           0.703224
#                  2024-02-03       1.582951           0.707836
#
#                              deltaPrevalence_7_percentage  invDeltaG_7  \
# location lineage date
# USA      BA.2.86 2024-01-30                     64.617600    25.609690
#                  2024-01-31                     66.384683    25.238824
#                  2024-02-01                     69.877420    24.782931
#                  2024-02-02                     70.322444    24.678140
#                  2024-02-03                     70.783589    24.562304
#
#                                   snr
# location lineage date
# USA      BA.2.86 2024-01-30  0.859247
#                  2024-01-31  0.861302
#                  2024-02-01  0.700452
#                  2024-02-02  0.732049
#                  2024-02-03  0.759141
#
# [5 rows x 21 columns]

# %%
# Get growth rate data for BA.2.86 on date 2024-02-02
df.loc['USA','BA.2.86','2024-02-02']
# Out:
# G_7                                0.030113
# G_7_linear                         3.057071
# N_7                                0.000000
# N_prev_7                           1.000000
# Prevalence_7                       0.002365
# Prevalence_7_percentage            0.236476
# confidenceInterval20               1.044012
# confidenceInterval35               1.879221
# confidenceInterval5                0.250563
# confidenceInterval50               2.797951
# confidenceInterval65               3.883724
# confidenceInterval80               5.345340
# confidenceInterval95               8.185052
# deltaG_7                           0.040522
# deltaG_7_linear                    4.176047
# deltaN_7                        3108.000000
# deltaN_prev_7                      1.582951
# deltaPrevalence_7                  0.703224
# deltaPrevalence_7_percentage      70.322444
# invDeltaG_7                       24.678140
# snr                                0.732049
# Name: (USA, BA.2.86, 2024-02-02), dtype: float64

# %%
df = outbreak_data.growth_rates('BA.2, BA.2.86' , 'USA')
  # Get the prevalence percentage and 80% confidence intervals for both lineages
df = df[[ 'Prevalence_7_percentage', 'confidenceInterval80']]
print(df)
# Out:
#                              Prevalence_7_percentage  confidenceInterval80
# location lineage date
# USA      BA.2    2024-01-30                 0.184008              5.410016
#                  2024-01-31                 0.180807              5.463835
#                  2024-02-01                 0.178196              5.519133
#                  2024-02-02                 0.176874              5.521128
#                  2024-02-03                 0.175658              5.520665
# ...                                              ...                   ...
#          BA.2.86 2024-03-07                 0.514831              6.592654
#                  2024-03-08                 0.512352              6.565807
#                  2024-03-09                 0.510145              6.595931
#                  2024-03-10                 0.508168              6.524510
#                  2024-03-11                 0.526594              6.380216
#
# [91 rows x 2 columns]

# %%
df = outbreak_data.sequence_counts('USA', sub_admin = True)
states = df.loc[['USA_US-NY', 'USA_US-FL', 'USA_US-CO', 'USA_US-TX']]
print(states)
# Out:
#              total_count
# location_id
# USA_US-NY         346598
# USA_US-FL         211068
# USA_US-CO         243188
# USA_US-TX         302701

# %%
df = outbreak_data.lineage_by_sub_admin('xbb.1.15', location='FRA')
df
# Out:
#                                  date           id  total_count  \
# name             query
#                  xbb.1.15  2024-05-13  FRA_FR-None            1
# Bretagne         xbb.1.15  2024-04-25    FRA_FR-BT            1
# Corse            xbb.1.15  2024-04-29    FRA_FR-CE            1
# Grand Est        xbb.1.15  2024-04-15    FRA_FR-AO            2
# Normandie        xbb.1.15  2024-04-08    FRA_FR-ND            2
# Occitanie        xbb.1.15  2024-05-06    FRA_FR-LP            3
# Pays de la Loire xbb.1.15  2024-04-02    FRA_FR-PL            5
#
#                            lineage_count  cum_total_count  cum_lineage_count  \
# name             query
#                  xbb.1.15              0             4504                  0
# Bretagne         xbb.1.15              0              398                  0
# Corse            xbb.1.15              0               51                  0
# Grand Est        xbb.1.15              0              784                  0
# Normandie        xbb.1.15              0              195                  0
# Occitanie        xbb.1.15              0              618                  0
# Pays de la Loire xbb.1.15              0              229                  0
#
#                            proportion  proportion_ci_lower  \
# name             query
#                  xbb.1.15         0.0         1.090158e-07
# Bretagne         xbb.1.15         0.0         1.232980e-06
# Corse            xbb.1.15         0.0         9.581002e-06
# Grand Est        xbb.1.15         0.0         6.261197e-07
# Normandie        xbb.1.15         0.0         2.514896e-06
# Occitanie        xbb.1.15         0.0         7.942326e-07
# Pays de la Loire xbb.1.15         0.0         2.141914e-06
#
#                            proportion_ci_upper
# name             query
#                  xbb.1.15             0.000558
# Bretagne         xbb.1.15             0.006288
# Corse            xbb.1.15             0.047830
# Grand Est        xbb.1.15             0.003198
# Normandie        xbb.1.15             0.012783
# Occitanie        xbb.1.15             0.004055
# Pays de la Loire xbb.1.15             0.010897

# %%
df = outbreak_data.wildcard_lineage('*.86*')
print(df)
# Out:
#             total_count
# name
# ba.2.86.1         10989
# b.1.177.86         5498
# ay.86              1105
# ba.2.86             995
# ba.2.86.3           366
# ba.2.86.2           323
# xbb.1.5.86          170
# ba.2.86.5            38
# b.1.1.86             26
# ba.2.86.4            10

# %%
df = outbreak_data.wildcard_location('*awai*')
print(df)
# Out:
#                        country country_id   division division_id  \
# id
# USA_US-HI        United States        USA     Hawaii          HI
# USA_US-HI_15001  United States        USA     Hawaii          HI
# IND_IN-RJ_SM             India        IND  Rajasthan          RJ
#
#                                             label  admin_level  total_count  \
# id
# USA_US-HI                   Hawaii, United States            1        28332
# USA_US-HI_15001     Hawaii, Hawaii, United States            2         3325
# IND_IN-RJ_SM     Sawai Madhopur, Rajasthan, India            2          138
#
#                        location location_id
# id
# USA_US-HI                   NaN         NaN
# USA_US-HI_15001          Hawaii       15001
# IND_IN-RJ_SM     Sawai Madhopur          SM

# %%
df = outbreak_data.mutation_details('*E484*')
print(df)
# Out:
#                   type gene ref_codon    pos alt_codon  is_synonymous ref_aa  \
# mutation
# S:E484L   substitution    S       GAA  23012       CTT          False      E
# S:E484A   substitution    S       GAA  23013       GCC          False      E
# S:E484R   substitution    S       GAA  23012       AGG          False      E
# S:E484V   substitution    S       GAA  23012       GTG          False      E
# S:E484T   substitution    S       GAA  23012       ACA          False      E
# S:E484D   substitution    S       GAA  23012       GAC          False      E
# S:E484H   substitution    S       GAA  23013       CAT          False      E
# S:E484K   substitution    S       GAA  23013       AAG          False      E
# S:E484Q   substitution    S       GAA  23011       CAA          False      E
# S:E484I   substitution    S       GAA  23011       ATA          False      E
#
#           codon_num alt_aa
# mutation
# S:E484L         484      L
# S:E484A         484      A
# S:E484R         484      R
# S:E484V         484      V
# S:E484T         484      T
# S:E484D         484      D
# S:E484H         484      H
# S:E484K         484      K
# S:E484Q         484      Q
# S:E484I         484      I

# %%
df = outbreak_data.lineage_cl_prevalence('BA.2.86.1', location = 'CAN')
print(df)
# Out:
#                       total_count  lineage_count  total_count_rolling  \
# date       query
# 2023-09-08 BA.2.86.1          270              1           251.000000
# 2023-09-09 BA.2.86.1          204              0           260.571429
# 2023-09-10 BA.2.86.1          227              0           266.285714
# 2023-09-11 BA.2.86.1          390              0           290.285714
# 2023-09-12 BA.2.86.1          409              1           300.142857
# ...                           ...            ...                  ...
# 2024-05-11 BA.2.86.1           20              0            37.285714
# 2024-05-12 BA.2.86.1           24              0            35.000000
# 2024-05-13 BA.2.86.1           69              0            36.285714
# 2024-05-14 BA.2.86.1           36              0            35.142857
# 2024-05-15 BA.2.86.1            3              0            31.428571
#
#                       lineage_count_rolling  proportion  proportion_ci_lower  \
# date       query
# 2023-09-08 BA.2.86.1               0.142857    0.000569             0.000002
# 2023-09-09 BA.2.86.1               0.142857    0.000548             0.000002
# 2023-09-10 BA.2.86.1               0.142857    0.000536             0.000002
# 2023-09-11 BA.2.86.1               0.142857    0.000492             0.000002
# 2023-09-12 BA.2.86.1               0.285714    0.000952             0.000002
# ...                                     ...         ...                  ...
# 2024-05-11 BA.2.86.1               0.000000    0.000000             0.000013
# 2024-05-12 BA.2.86.1               0.000000    0.000000             0.000014
# 2024-05-13 BA.2.86.1               0.000000    0.000000             0.000014
# 2024-05-14 BA.2.86.1               0.000000    0.000000             0.000014
# 2024-05-15 BA.2.86.1               0.000000    0.000000             0.000016
#
#                       proportion_ci_upper
# date       query
# 2023-09-08 BA.2.86.1             0.009948
# 2023-09-09 BA.2.86.1             0.009569
# 2023-09-10 BA.2.86.1             0.009390
# 2023-09-11 BA.2.86.1             0.008617
# 2023-09-12 BA.2.86.1             0.008331
# ...                                   ...
# 2024-05-11 BA.2.86.1             0.065207
# 2024-05-12 BA.2.86.1             0.068777
# 2024-05-13 BA.2.86.1             0.066944
# 2024-05-14 BA.2.86.1             0.068777
# 2024-05-15 BA.2.86.1             0.077230
#
# [251 rows x 7 columns]

# %%
df = outbreak_data.lineage_cl_prevalence('BA.2', location = 'CAN', 
                                         datemin = '2022-03-01',
                                         datemax = '2022-03-08')
print(df)
# Out:
#                   total_count  lineage_count  total_count_rolling  \
# date       query
# 2022-03-01 BA.2           569             77           569.000000
# 2022-03-02 BA.2           626             71           597.500000
# 2022-03-03 BA.2           572             78           589.000000
# 2022-03-04 BA.2           540             72           576.750000
# 2022-03-05 BA.2           413             70           544.000000
# 2022-03-06 BA.2           457             59           529.500000
# 2022-03-07 BA.2           549             75           532.285714
# 2022-03-08 BA.2           653            114           544.285714
#
#                   lineage_count_rolling  proportion  proportion_ci_lower  \
# date       query
# 2022-03-01 BA.2               77.000000    0.135325             0.109091
# 2022-03-02 BA.2               74.000000    0.123849             0.099185
# 2022-03-03 BA.2               75.333333    0.127900             0.102257
# 2022-03-04 BA.2               74.500000    0.129172             0.102845
# 2022-03-05 BA.2               73.600000    0.135294             0.109177
# 2022-03-06 BA.2               71.166667    0.134404             0.106981
# 2022-03-07 BA.2               71.714286    0.134729             0.108272
# 2022-03-08 BA.2               77.000000    0.141470             0.114181
#
#                   proportion_ci_upper
# date       query
# 2022-03-01 BA.2              0.165257
# 2022-03-02 BA.2              0.151938
# 2022-03-03 BA.2              0.156063
# 2022-03-04 BA.2              0.157372
# 2022-03-05 BA.2              0.166742
# 2022-03-06 BA.2              0.164927
# 2022-03-07 BA.2              0.166358
# 2022-03-08 BA.2              0.172709

# %%
df = outbreak_data.gr_significance(location='Global', n=5)
print(df)
# Out:
#                     _id _score growing   leaf     loc                 sig  \
# lin
# JN.1.1    Global_JN.1.1   None    true   true  Global   170.5345544056284
# JN.1.4    Global_JN.1.4   None    true   true  Global  148.67142485884114
# JN.1.22  Global_JN.1.22   None    true   true  Global  125.34771448608038
# JN.1+      Global_JN.1+   None    true  false  Global   115.0086253690486
# JN.1.7    Global_JN.1.7   None    true   true  Global  103.52483890881427
#
#                         snr
# lin
# JN.1.1   12.915667590790331
# JN.1.4   12.041819797365195
# JN.1.22  11.034042953153367
# JN.1+    10.556798749279736
# JN.1.7   10.000270940090726

# %%
# df = outbreak_data.get_wastewater_samples_by_mutation(site =1003) #problems with this endpoint
# df

df = outbreak_data.get_wastewater_samples_by_lineage('EG.5.1', server = 'dev.outbreak.info') #also broken
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 4
#       1 # df = outbreak_data.get_wastewater_samples_by_mutation(site =1003) #problems with this endpoint
#       2 # df
# ----> 4 df = outbreak_data.get_wastewater_samples_by_lineage('EG.5.1', server = 'dev.outbreak.info') #also broken
#       5 df
#
# File ~/opt/anaconda3/envs/spyder-env/lib/python3.9/site-packages/outbreak_data/outbreak_data.py:438, in get_wastewater_samples_by_lineage(lineage, descendants, min_abundance, **req_args)
#     436 namequery = f'name:{lineage}' if not descendants else f'crumbs:*;{lineage};*'
#     437 data = _get_outbreak_data('wastewater_demix/query', f"q=abundance:>={min_abundance} AND {namequery}", collect_all=True, **req_args)
# --> 438 return _get_ww_results(data).drop(columns=['_score', '_id'])
#
# File ~/opt/anaconda3/envs/spyder-env/lib/python3.9/site-packages/pandas/core/frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
#    5352     )
#
# File ~/opt/anaconda3/envs/spyder-env/lib/python3.9/site-packages/pandas/core/generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File ~/opt/anaconda3/envs/spyder-env/lib/python3.9/site-packages/pandas/core/generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File ~/opt/anaconda3/envs/spyder-env/lib/python3.9/site-packages/pandas/core/indexes/base.py:7000, in Index.drop(self, labels, errors)
#    6998 if mask.any():
#    6999     if errors != "ignore":
# -> 7000         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7001     indexer = indexer[~mask]
#    7002 return self.delete(indexer)
#
# KeyError: "['_score', '_id'] not found in axis"

# %%
df = outbreak_data.known_mutations('BA.2.86')
print(df)
# Out:
#               mutation_count  lineage_count  lineage   gene      ref_aa  \
# mutation
# e:t9i                    995            995  BA.2.86      E           T
# orf1b:r1315c             995            995  BA.2.86  ORF1b           R
# orf1b:p314l              994            995  BA.2.86  ORF1b           P
# orf3a:t223i              994            995  BA.2.86  ORF3a           T
# n:r203k                  992            995  BA.2.86      N           R
# ...                      ...            ...      ...    ...         ...
# s:r403k                  858            995  BA.2.86      S           R
# s:del25/27               832            995  BA.2.86      S  S:DEL25/27
# s:l24s                   832            995  BA.2.86      S           L
# s:n460k                  808            995  BA.2.86      S           N
# s:s477n                  799            995  BA.2.86      S           S
#
#                 alt_aa  codon_num  codon_end          type  prevalence  \
# mutation
# e:t9i                I          9        NaN  substitution    1.000000
# orf1b:r1315c         C       1315        NaN  substitution    1.000000
# orf1b:p314l          L        314        NaN  substitution    0.998995
# orf3a:t223i          I        223        NaN  substitution    0.998995
# n:r203k              K        203        NaN  substitution    0.996985
# ...                ...        ...        ...           ...         ...
# s:r403k              K        403        NaN  substitution    0.862312
# s:del25/27    DEL25/27         25       27.0      deletion    0.836181
# s:l24s               S         24        NaN  substitution    0.836181
# s:n460k              K        460        NaN  substitution    0.812060
# s:s477n              N        477        NaN  substitution    0.803015
#
#               change_length_nt
# mutation
# e:t9i                      NaN
# orf1b:r1315c               NaN
# orf1b:p314l                NaN
# orf3a:t223i                NaN
# n:r203k                    NaN
# ...                        ...
# s:r403k                    NaN
# s:del25/27                 9.0
# s:l24s                     NaN
# s:n460k                    NaN
# s:s477n                    NaN
#
# [81 rows x 11 columns]

# %%
df = outbreak_data.mutation_prevalences('orf1b:r1315c, s:l24s', 'USA' ,'BA.2.86')
print(df)
# Out:
#              pangolin_lineage  lineage_count  mutation_count  proportion  \
# query
#   s:l24s              ba.2.86             84              77    0.916667
# orf1b:r1315c          ba.2.86             84              84    1.000000
#
#               proportion_ci_lower  proportion_ci_upper
# query
#   s:l24s                 0.843358             0.961949
# orf1b:r1315c             0.970625             0.999994

# %%
date = outbreak_data.most_recent_cl_data('BA.2.86', location = 'USA_US-NY' )
date
# Out:
# Timestamp('2024-01-16 00:00:00')

# %%
lin0 = outbreak_data.known_mutations("xbb", freq = 0.80)
lin0
# Out:
#               mutation_count  lineage_count lineage   gene        ref_aa  \
# mutation
# s:d614g                 4487           4499     xbb      S             D
# e:t9i                   4485           4499     xbb      E             T
# s:h655y                 4482           4499     xbb      S             H
# orf1b:r1315c            4476           4499     xbb  ORF1b             R
# orf3a:t223i             4473           4499     xbb  ORF3a             T
# ...                      ...            ...     ...    ...           ...
# s:g446s                 3791           4499     xbb      S             G
# s:t376a                 3765           4499     xbb      S             T
# s:del144/144            3746           4499     xbb      S  S:DEL144/144
# s:l368i                 3738           4499     xbb      S             L
# s:v445p                 3694           4499     xbb      S             V
#
#                   alt_aa  codon_num  codon_end          type  prevalence  \
# mutation
# s:d614g                G        614        NaN  substitution    0.997333
# e:t9i                  I          9        NaN  substitution    0.996888
# s:h655y                Y        655        NaN  substitution    0.996221
# orf1b:r1315c           C       1315        NaN  substitution    0.994888
# orf3a:t223i            I        223        NaN  substitution    0.994221
# ...                  ...        ...        ...           ...         ...
# s:g446s                S        446        NaN  substitution    0.842632
# s:t376a                A        376        NaN  substitution    0.836853
# s:del144/144  DEL144/144        144      144.0      deletion    0.832629
# s:l368i                I        368        NaN  substitution    0.830851
# s:v445p                P        445        NaN  substitution    0.821071
#
#               change_length_nt
# mutation
# s:d614g                    NaN
# e:t9i                      NaN
# s:h655y                    NaN
# orf1b:r1315c               NaN
# orf3a:t223i                NaN
# ...                        ...
# s:g446s                    NaN
# s:t376a                    NaN
# s:del144/144               3.0
# s:l368i                    NaN
# s:v445p                    NaN
#
# [65 rows x 11 columns]
